# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83381301.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_16420536.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60662427.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55547895.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40980954.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_94300282.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41634150.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63945952.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87504741.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88977052.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86791179.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83159157.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41203026.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58373073.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24628820.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_71782410.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58271369.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66920927.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58770316.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87575105.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_1860442.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59727027.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_23818294.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_38135240.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32184872.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_19334701.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34454249.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_43487413.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48786741.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75569213.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66619499.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61603446.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41516779.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62029605.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68304807.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_14895893.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_46551436.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99592117.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48896776.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55531335.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85005588.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76896189.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_94185590.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60639644.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63684224.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83526785.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_27508829.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90397257.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62311806.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_47938224.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61061299.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45192736.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_97555206.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_37821882.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_29532503.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86733541.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86361833.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59134510.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32696523.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_17901542.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99615492.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64967705.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_98493897.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61801211.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_28403324.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_47189188.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55548559.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59147550.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75524144.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83092876.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74129649.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82404406.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_827174.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85317312.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_542648.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73699986.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_47491522.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_43850435.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_33744455.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62719561.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85298282.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69943347.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72688390.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_1533939.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_25350223.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_44046935.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_36005445.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_1140162.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61015137.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67035479.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80262272.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45786766.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82398460.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_84367443.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69533380.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81738693.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74082906.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_22020161.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58390093.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70146044.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48774268.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74381650.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67251966.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99371530.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51166925.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_30086299.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_42066848.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72265463.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32295459.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89873425.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_38964043.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88062904.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68266971.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69149556.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86238135.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85565600.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68703833.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49693489.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70077335.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81616035.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74661109.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63891020.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_837497.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24430950.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66070542.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_97059410.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86290095.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48206205.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85359060.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64611370.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80782079.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_1002988.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_18983204.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_21993844.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41486091.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61941250.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_10880014.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32049146.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89434732.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76572902.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_1530359.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78181316.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80590798.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48497148.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_47106603.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_9022977.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78901161.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93444249.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_71062576.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_43832019.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77164510.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40598949.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81492509.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48062930.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75651293.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_3626985.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_30485739.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63954774.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26052517.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_37219157.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_22689784.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59403895.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_2445983.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51653557.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80664999.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77212710.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87351776.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56587348.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59757916.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59193905.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57558674.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_13595544.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77647521.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_7162356.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80974742.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73851284.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85671096.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_5034166.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32541990.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79766006.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57971211.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45407960.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59175942.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74304910.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_36029645.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85358935.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85844114.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82614671.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_84221412.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_39675806.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79047665.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_29122482.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86029296.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_4110190.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83080805.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_16518895.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_44069308.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55639126.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_2537299.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86873968.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59063432.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_52059317.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89807637.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_38153970.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55307056.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_689477.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_43019666.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_95031305.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56397251.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93179598.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76658307.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_46473737.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26049808.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87121740.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41339602.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72834562.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62845419.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73773332.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34151919.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24676509.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64158482.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_36844836.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67001978.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53302035.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_30417695.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_1398330.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50549952.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80012919.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_10334657.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55060607.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_22337279.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99294056.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_91759610.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80385267.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83962836.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83453727.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_96760159.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34595257.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_96004413.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_92614914.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67513221.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48224850.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_23027253.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40883598.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59166919.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66927160.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99220085.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41507980.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_33027616.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79502121.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67069084.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93035250.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55726165.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_19049026.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80100388.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63215798.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57786165.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_5380955.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70708379.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_46733683.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_96029654.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73726678.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_35844142.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40276072.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56687570.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67333296.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45386398.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_38528566.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_628195.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85597029.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_25840805.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56397624.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53835549.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_13890889.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59155909.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77779002.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60230158.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24071403.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93528580.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65589113.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_35078810.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_13856277.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_30322675.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80245185.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78819873.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_84474655.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_43691959.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56879859.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66407171.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34212026.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32458112.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60654223.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88807653.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34648971.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73347083.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_44541408.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89013819.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26587909.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57551258.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70386067.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89760581.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_25414314.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88286495.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66224075.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40849048.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68575640.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_6663318.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77341234.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99611328.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78459883.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26529662.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87154721.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57144560.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59285134.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53819919.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40716669.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78451397.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64316446.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_71390173.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51724489.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67814499.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24636311.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72262355.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_2663198.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63877787.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_39164114.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61968210.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53867980.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86291186.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65491151.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_98905396.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77528446.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86838114.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99935281.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81911975.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34233504.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_97633558.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76498850.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59158321.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_91215241.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73516602.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_46880995.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_47812344.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55692217.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_94486565.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65072310.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89974440.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53340094.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_18855831.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56775690.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50577893.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_29828446.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41197818.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_6645021.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_19159251.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69898483.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64142526.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26716156.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79449093.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48340935.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_37754732.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65225485.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_29386741.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77541001.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34466828.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67632074.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88963905.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_95041197.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79989279.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_601446.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_28869535.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59727678.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40186731.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_59179428.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87508381.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66833810.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_38093113.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63689621.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73217693.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61120868.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81075968.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85096397.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32240111.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65654036.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_27815773.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_42951954.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90761475.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81831922.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72829677.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72083086.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_25833290.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49274339.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_95952158.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88142963.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_6737079.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67477634.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60429136.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74528581.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64602261.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55004493.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87234342.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75793471.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_35252724.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_43414195.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70429839.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_7804222.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_54886976.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77407026.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81372190.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48561626.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79243286.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_19529410.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57887267.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53464768.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62570801.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55480279.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_71599013.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83963498.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64041463.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75127747.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68098918.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88775600.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53463634.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67844249.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77414731.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89352243.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76327857.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_35728189.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76558136.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60894672.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26785778.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77833052.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45196865.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77040932.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67844155.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_25233426.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51022886.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_33325770.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55287208.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_18523618.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32741073.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74526007.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69700891.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88317106.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67418046.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81125043.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_13096216.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72749688.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85035254.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88323005.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83316504.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_94281609.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77080158.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_98126400.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41519353.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76330167.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75556581.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_44227133.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_39980699.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48082926.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_54045304.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80907731.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63315283.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50801198.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_16747891.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67519900.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73612762.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40708975.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87010571.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78859615.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88505409.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_35845439.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_96065661.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_27661490.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45733686.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66432110.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70046469.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48877380.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76008114.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61945680.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72024974.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74077477.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66408047.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56932429.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66868831.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_20261373.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89242228.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72453787.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40935975.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90328795.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68719732.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80925075.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81995407.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_1049110.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67475355.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_31826806.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57494584.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53910597.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49231288.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62519039.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66306116.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90359183.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90131280.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_97005763.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_42942109.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26902577.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58699528.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65290509.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_355161.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99877521.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_13908398.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_28266816.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_23116606.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_57063488.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32153426.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70543418.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_52125657.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99633476.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_6234228.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49322945.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77593066.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50534961.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82876716.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_27911713.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26519313.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60910729.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_26091732.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_28809123.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_28169462.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90738714.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_21057027.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76191571.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74764290.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_91347138.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79896838.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61848424.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_22907015.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56333206.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72269077.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_17977538.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81600458.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24836663.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83685763.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_8266328.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77856880.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82546595.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_31941945.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68409285.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77071144.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55551847.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34236475.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73065763.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_46938855.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78020565.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77892425.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_92645240.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76306949.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83972557.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_7976230.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65786260.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50411547.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_42719029.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53140645.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_33828405.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58867971.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_66324503.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81041821.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_802994.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51444556.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_18077846.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76047788.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72846586.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53245967.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87982102.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73894323.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45516392.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74852052.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65345495.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45436563.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88251431.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_98512557.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87974606.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69855664.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50816745.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_5082081.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_15972138.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_17415128.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85521704.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_504314.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90925461.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75967218.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67144580.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_14207673.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55668881.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_28402327.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89949377.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49836005.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64436375.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73946810.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56851642.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53936589.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89939018.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73166178.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82402462.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81203991.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_39881040.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75791637.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69156094.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51037652.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81761009.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_8823387.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_89083825.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49443347.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76464001.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55874923.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76965103.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62621424.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62169976.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83170569.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_42716286.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_90370277.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_45370303.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63486506.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85031605.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85020756.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65339053.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_38851874.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68891917.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49520447.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87494111.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_54188477.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_22870246.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80130618.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50437359.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53212019.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62853072.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93675349.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99984580.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24257117.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85674975.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40216038.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78932392.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77780349.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_42772446.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61285240.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_56902918.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_54856407.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_39100001.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_71382499.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_96310289.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65998976.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_24456457.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61650771.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88544005.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93672293.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_95269310.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79809839.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70263723.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_85775287.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_13922710.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_19310857.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67248345.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72040679.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34717920.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_76048195.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99812453.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77113342.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_16212398.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58330896.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77049363.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75068519.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79192991.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_47796763.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_19922816.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74677940.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51231151.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68973241.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_78278520.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65638052.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_98653132.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_68521047.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_70371123.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77275050.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53093420.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62503961.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_13566250.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_63034428.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_69615433.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74464134.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86546836.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82026666.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73464276.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_87371413.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_83455613.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_52907497.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_80018486.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_30563705.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_84968771.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_38879985.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_60014572.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_73144336.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41243504.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_17865546.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75217821.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_92529681.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_49240120.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_7591550.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75785789.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_62437936.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81949935.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_37142792.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_58397428.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_32043425.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_37174842.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93161138.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_61877230.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_92554910.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_75942265.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34341584.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_27442222.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_71949691.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_77087736.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_25917945.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40571432.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_97194124.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_86275657.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82257044.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_44423728.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_25846449.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_31302400.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_71108617.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53341437.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_67568574.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_29220729.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79962167.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_55207260.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_98508447.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41111086.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_91038482.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_30617136.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_65575863.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_51161053.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_29481436.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_93011205.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_72170042.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_64283985.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_79316708.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_41469432.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_46645146.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_53236084.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_50014673.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_34146389.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_81167742.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_88791769.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_36391516.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_74564230.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_48313852.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_99870742.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_8592139.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_40385499.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_82364154.jpg
# /kaggle/input/fer13-cleaned-dataset/fear/Training_22765648.jpg
# ...
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_42627345.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37378857.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_98465236.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_64054564.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_82760129.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_71662293.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_6795722.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_39888899.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_72538544.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_63421852.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_22649558.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_75024838.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_95020990.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_47662199.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_32677468.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_15779355.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_3205364.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_78075233.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_213426.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37701679.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_10351870.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37638807.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_58452962.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_71155257.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_97878266.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_59040744.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_44018238.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_82344165.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_94600860.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_76421399.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_69555502.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_94686725.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_24747938.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_95114564.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_41553688.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_59951556.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_78869480.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_3735907.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_6781300.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_26813833.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_12624768.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_95155623.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_14765906.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37316795.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_89406587.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_55291294.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_19943368.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_83087543.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_32094496.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_48520502.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_26957616.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_1896580.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_5974733.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_26435220.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_12162299.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_75406146.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_63038067.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_82467947.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_61334784.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_66510505.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_45026187.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_16412701.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_86089242.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_504095.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_11022927.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_41141425.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_3730588.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_62231208.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_14814487.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_8208971.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_62283512.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_64473671.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_61966651.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_58600189.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_26029515.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_91902431.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_68280022.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37076689.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_72685911.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_20652019.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_68342297.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_49684181.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_35061201.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_80363659.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_10041793.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_75291453.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_21819771.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_28732002.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_49462272.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_2633988.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_66811915.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_27786235.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37678502.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_19336415.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_26626531.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_8843568.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_12088249.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_73871576.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_38612785.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_50701107.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_88605927.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_53221341.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_98548617.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_83733203.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_21832003.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_91139923.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_53957000.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_3375179.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_8252925.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_13679829.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_45585370.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_72402414.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_30623479.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_87164213.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_25980178.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_32665206.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_7280964.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_48104056.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_36337282.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_2542413.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_13984132.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_26609510.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_82046872.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_65755353.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_38351708.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_56051240.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_40623034.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_32153227.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_39854983.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_57616785.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_98208156.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_14983397.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_68076746.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_43587025.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_21932094.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_79554142.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_92870563.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_59279558.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_85066140.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_92117550.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_93180869.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_98955512.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_3980094.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37057076.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_68731696.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_12626931.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_91366900.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_72750895.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_46755128.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_75327572.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_86241738.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_96441377.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_83059975.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_52789538.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_77342134.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_37044280.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_34846494.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_96728003.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_29247723.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_61593114.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_71978341.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_88295383.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_20751436.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_25901725.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_93612315.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_25095860.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_36197249.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_90220612.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_3602825.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_73820637.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_65915429.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_67372023.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_8029040.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_2297154.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_91201089.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_36626081.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_75940345.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_11243256.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_76096394.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_8243976.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_96626401.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_32882616.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_25493909.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_34626576.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_60390619.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_32568568.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_6652733.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_25344449.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_44398864.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_84874860.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_19393663.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_18547719.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_89041010.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_82980352.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_27397218.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_32953674.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_9923345.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_42943828.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_79122470.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_6523050.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_71740838.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_91556069.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_58064767.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_12537205.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_40239819.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_81415548.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_98969875.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_24603345.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_35619379.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_90223076.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_72853690.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_12420563.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_29488498.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_95340775.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_47296965.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_9459040.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_67838464.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_13595569.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_73365770.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_28164787.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_7890159.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_46359620.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_68348762.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_59572969.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_38845789.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_96634166.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_22892610.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_97981340.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_29567767.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_94902624.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_9471172.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_63658142.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_65370033.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_65504805.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_22967853.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_70863256.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_61114205.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_71268969.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_30142693.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_77043425.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_94498856.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_80511536.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_69450321.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_52837344.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_39519212.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_69463946.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_61388556.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_30966580.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_92744141.jpg
# /kaggle/input/fer13-cleaned-dataset/Happy/Training_42384294.jpg

# %%
import os
import cv2
import math
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, GlobalAvgPool2D, GlobalMaxPool2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.utils import plot_model

from keras.utils import np_utils

# %%
# Reading input path
INPUT_PATH = "../input/fer13-cleaned-dataset/"

# %%
# count of emotions.
total_images = 0
for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
        total_images += 1
    print(f"{dir_} has {count} number of images")
    
print(f"\ntotal images are {total_images}")
# Out:
# fear has 2535 number of images
# Angry has 2832 number of images
# Neutral has 4295 number of images
# disgust has 380 number of images
# Happy has 6834 number of images
#
# total images are 16876

# %% [markdown]
# The above values shows that 'Happy' images count is majority and 'Disgust' images count is in minority. So i would like to drop minority count images from data.

# %%
# Removing disgust emotion
TOP_EMOTIONS = ["fear", "Happy", "Neutral", "Angry"]
total_images -= 380
total_images
# Out:
# 16496

# %%
#Loading images into an array
img_arr = np.empty(shape=(total_images,48,48,3))
img_label = np.empty(shape=(total_images))
label_to_text = {}

i = 0
e = 0
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        label_to_text[e] = dir_
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            img_arr[i] = cv2.imread(INPUT_PATH + dir_ + "/" + f)
            img_label[i] = e
            i += 1
        print(f"loaded all {dir_} images to numpy arrays")
        e += 1

img_arr.shape, img_label
# Out:
# loaded all fear images to numpy arrays
# loaded all Angry images to numpy arrays
# loaded all Neutral images to numpy arrays
# loaded all Happy images to numpy arrays
# ((16496, 48, 48, 3), array([0., 0., 0., ..., 3., 3., 3.]))

# %%
# Labels are converted to textual format
label_to_text
# Out:
# {0: 'fear', 1: 'Angry', 2: 'Neutral', 3: 'Happy'}

# %%
#Plot of emotions
fig = pyplot.figure(1, (8,8))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label==k)[0], size=4, replace=False)
    sample_images = img_arr[sample_indices]
    for img in sample_images:
        idx += 1
        ax = pyplot.subplot(4,4,idx)
        ax.imshow(img[:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])
        pyplot.tight_layout()

# %%
#Converting class vector to binary class matrix
img_label = np_utils.to_categorical(img_label)
img_label.shape
# Out:
# (16496, 4)

# %%
#Normalizing the data
img_arr = img_arr / 255.

# %%
# Splitting Data into test and train
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=0.9, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14846, 48, 48, 3), (1650, 48, 48, 3), (14846, 4), (1650, 4))

# %%
#Deleting the array of images
del img_arr
del img_label

# %%
# Defining width, height, depth, and number of classes
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = y_train.shape[1]

# %%
#Defining transfer learning model
mobile_net = MobileNet(
    input_shape = (img_width, img_height, img_depth),
    include_top = False,
    weights = "imagenet",
    classes = num_classes
)

x = mobile_net.layers[-14].output
global_pool = GlobalMaxPool2D(name="global_pool")(x)
out = Dense(num_classes, activation="softmax", name="out_layer")(global_pool)

model = Model(inputs=mobile_net.input, outputs=out)
# Out:
# 2021-11-12 05:35:01.128289: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:01.243714: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:01.244461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:01.245633: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-12 05:35:01.246871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:01.247616: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:01.248272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:03.101882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:03.102736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:03.103414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 05:35:03.104007: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
#Summary of the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 48, 48, 3)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 24, 24, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 24, 24, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 24, 24, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 24, 24, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 24, 24, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 24, 24, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 24, 24, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 24, 24, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 24, 24, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 25, 25, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 12, 12, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 12, 12, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 12, 12, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 12, 12, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 12, 12, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 12, 12, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 13, 13, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 6, 6, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 6, 6, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 6, 6, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 6, 6, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 6, 6, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 6, 6, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 7, 7, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 3, 3, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 3, 3, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 3, 3, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 3, 3, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# global_pool (GlobalMaxPoolin (None, 512)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 4)                 2052
# =================================================================
# Total params: 1,629,892
# Trainable params: 1,615,172
# Non-trainable params: 14,720
# _________________________________________________________________

# %%
#Visualizing the model
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True, show_layer_names=True, expand_nested=True, to_file='model.png')

# %%
for layer in model.layers[:15]:
    layer.trainable = False

# %%
#Augumenting Training images
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    zca_whitening=False,
)
train_datagen.fit(X_train)

# %%
from keras.models import model_from_json

# %%
"""
Using two callbacks one is `early stopping` for avoiding overfitting of training data
and other `ReduceLROnPlateau` for learning rate.
"""
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00008,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.25,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)
callbacks = [
    early_stopping,
    lr_scheduler]

# %%
#Fitting the model
batch_size = 25
epochs = 40

optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07),
    optimizers.Adam(0.01),
]

model.compile(
        loss='categorical_crossentropy',
        optimizer=optims[1],
        metrics=['accuracy']
)

history = model.fit_generator(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data=(X_test, y_test),
    steps_per_epoch=len(X_train) / batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)

model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
    
model.save("model.h5")
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021-11-12 05:35:07.212495: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/40
# 2021-11-12 05:35:10.521842: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 593/593 [==============================] - 26s 30ms/step - loss: 1.4688 - accuracy: 0.4450 - val_loss: 1.3670 - val_accuracy: 0.3424
# Epoch 2/40
# 593/593 [==============================] - 18s 30ms/step - loss: 1.1102 - accuracy: 0.5431 - val_loss: 1.1633 - val_accuracy: 0.5127
# Epoch 3/40
# 593/593 [==============================] - 17s 29ms/step - loss: 0.9874 - accuracy: 0.5952 - val_loss: 0.8879 - val_accuracy: 0.6570
# Epoch 4/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.9260 - accuracy: 0.6272 - val_loss: 0.9437 - val_accuracy: 0.6303
# Epoch 5/40
# 593/593 [==============================] - 18s 29ms/step - loss: 0.8851 - accuracy: 0.6439 - val_loss: 0.8564 - val_accuracy: 0.6648
# Epoch 6/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.8623 - accuracy: 0.6574 - val_loss: 0.8550 - val_accuracy: 0.6630
# Epoch 7/40
# 593/593 [==============================] - 19s 32ms/step - loss: 0.8416 - accuracy: 0.6646 - val_loss: 0.8232 - val_accuracy: 0.6842
# Epoch 8/40
# 593/593 [==============================] - 18s 31ms/step - loss: 0.8164 - accuracy: 0.6765 - val_loss: 0.8257 - val_accuracy: 0.6812
# Epoch 9/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.8062 - accuracy: 0.6831 - val_loss: 0.7808 - val_accuracy: 0.6842
# Epoch 10/40
# 593/593 [==============================] - 18s 31ms/step - loss: 0.8007 - accuracy: 0.6853 - val_loss: 0.8623 - val_accuracy: 0.6782
# Epoch 11/40
# 593/593 [==============================] - 18s 29ms/step - loss: 0.7888 - accuracy: 0.6877 - val_loss: 0.8283 - val_accuracy: 0.6594
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 12/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.7296 - accuracy: 0.7153 - val_loss: 0.6914 - val_accuracy: 0.7291
# Epoch 13/40
# 593/593 [==============================] - 19s 32ms/step - loss: 0.6974 - accuracy: 0.7267 - val_loss: 0.6645 - val_accuracy: 0.7327
# Epoch 14/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.6932 - accuracy: 0.7285 - val_loss: 0.6659 - val_accuracy: 0.7352
# Epoch 15/40
# 593/593 [==============================] - 18s 31ms/step - loss: 0.6751 - accuracy: 0.7341 - val_loss: 0.6705 - val_accuracy: 0.7279
# Epoch 16/40
# 593/593 [==============================] - 18s 31ms/step - loss: 0.6689 - accuracy: 0.7374 - val_loss: 0.6706 - val_accuracy: 0.7261
# Epoch 17/40
# 593/593 [==============================] - 19s 33ms/step - loss: 0.6596 - accuracy: 0.7465 - val_loss: 0.6405 - val_accuracy: 0.7467
# Epoch 18/40
# 593/593 [==============================] - 19s 32ms/step - loss: 0.6581 - accuracy: 0.7445 - val_loss: 0.6503 - val_accuracy: 0.7400
# Epoch 19/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.6517 - accuracy: 0.7477 - val_loss: 0.6602 - val_accuracy: 0.7291
# Epoch 20/40
# 593/593 [==============================] - 19s 32ms/step - loss: 0.6455 - accuracy: 0.7490 - val_loss: 0.6581 - val_accuracy: 0.7376
# Epoch 21/40
# 593/593 [==============================] - 18s 31ms/step - loss: 0.6396 - accuracy: 0.7512 - val_loss: 0.6498 - val_accuracy: 0.7424
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 22/40
# 593/593 [==============================] - 19s 32ms/step - loss: 0.6144 - accuracy: 0.7600 - val_loss: 0.6288 - val_accuracy: 0.7509
# Epoch 23/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.6046 - accuracy: 0.7632 - val_loss: 0.6311 - val_accuracy: 0.7473
# Epoch 24/40
# 593/593 [==============================] - 20s 33ms/step - loss: 0.6017 - accuracy: 0.7651 - val_loss: 0.6292 - val_accuracy: 0.7461
# Epoch 25/40
# 593/593 [==============================] - 17s 28ms/step - loss: 0.5969 - accuracy: 0.7659 - val_loss: 0.6242 - val_accuracy: 0.7467
# Epoch 26/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.5948 - accuracy: 0.7686 - val_loss: 0.6310 - val_accuracy: 0.7485
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 27/40
# 593/593 [==============================] - 19s 32ms/step - loss: 0.5834 - accuracy: 0.7731 - val_loss: 0.6291 - val_accuracy: 0.7473
# Epoch 28/40
# 593/593 [==============================] - 17s 29ms/step - loss: 0.5893 - accuracy: 0.7698 - val_loss: 0.6240 - val_accuracy: 0.7485
# Epoch 29/40
# 593/593 [==============================] - 20s 34ms/step - loss: 0.5836 - accuracy: 0.7733 - val_loss: 0.6277 - val_accuracy: 0.7479
# Epoch 30/40
# 593/593 [==============================] - 17s 28ms/step - loss: 0.5788 - accuracy: 0.7755 - val_loss: 0.6273 - val_accuracy: 0.7503
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 31/40
# 593/593 [==============================] - 20s 34ms/step - loss: 0.5837 - accuracy: 0.7736 - val_loss: 0.6276 - val_accuracy: 0.7497
# Epoch 32/40
# 593/593 [==============================] - 17s 28ms/step - loss: 0.5803 - accuracy: 0.7764 - val_loss: 0.6247 - val_accuracy: 0.7515
# Epoch 33/40
# 593/593 [==============================] - 17s 29ms/step - loss: 0.5816 - accuracy: 0.7746 - val_loss: 0.6274 - val_accuracy: 0.7497
# Epoch 34/40
# 593/593 [==============================] - 21s 35ms/step - loss: 0.5797 - accuracy: 0.7734 - val_loss: 0.6264 - val_accuracy: 0.7491
# Epoch 35/40
# 593/593 [==============================] - 17s 29ms/step - loss: 0.5773 - accuracy: 0.7752 - val_loss: 0.6263 - val_accuracy: 0.7509
# Epoch 36/40
# 593/593 [==============================] - 18s 30ms/step - loss: 0.5808 - accuracy: 0.7766 - val_loss: 0.6280 - val_accuracy: 0.7491
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 9.765624781721272e-06.
# Epoch 37/40
# 593/593 [==============================] - 17s 29ms/step - loss: 0.5762 - accuracy: 0.7781 - val_loss: 0.6269 - val_accuracy: 0.7503
# Epoch 38/40
# 593/593 [==============================] - 21s 34ms/step - loss: 0.5708 - accuracy: 0.7780 - val_loss: 0.6269 - val_accuracy: 0.7503
# Epoch 39/40
# 593/593 [==============================] - 17s 29ms/step - loss: 0.5791 - accuracy: 0.7737 - val_loss: 0.6261 - val_accuracy: 0.7497
# Epoch 40/40
# 593/593 [==============================] - 21s 35ms/step - loss: 0.5685 - accuracy: 0.7810 - val_loss: 0.6267 - val_accuracy: 0.7509
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 2.441406195430318e-06.

# %%
model.save('/kaggle/working/transfer_learning.h5')

# %%
#Fetching accuracy and loss of test and train dataset
score = model.evaluate(X_test, y_test,verbose=0)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])
test_image = X_test[0:1]
print (test_image.shape)

score = model.evaluate(X_train, y_train,verbose=0) 
print('Train Loss:', score[0])
print('Train accuracy:', score[1])
train_image = X_train[0:1]
print (test_image.shape)
# Out:
# Test Loss: 0.6267307996749878
# Test accuracy: 0.7509090900421143
# (1, 48, 48, 3)
# Train Loss: 0.5381519794464111
# Train accuracy: 0.7915936708450317
# (1, 48, 48, 3)

# %%
#Visualization of model performance
import matplotlib.pyplot as plt
train_loss= history.history['loss']
val_loss= history.history['val_loss']
train_acc= history.history['accuracy']
val_acc= history.history['val_accuracy']

epochs = range(len(train_acc))

plt.plot(epochs,train_loss,'r', label='train_loss')
plt.plot(epochs,val_loss,'b', label='val_loss')
plt.title('train_loss vs val_loss')
plt.legend()
plt.figure()

plt.plot(epochs,train_acc,'r', label='train_acc')
plt.plot(epochs,val_acc,'b', label='val_acc')
plt.title('train_acc vs val_acc')
plt.legend()
plt.figure()
plt.savefig('model_epoch_history.png')

# %%
# Fetching label to text 
label_to_text
# Out:
# {0: 'fear', 1: 'Angry', 2: 'Neutral', 3: 'Happy'}

# %%
#Converting label_to_text to text_to_label
text_to_label = dict((v,k) for k,v in label_to_text.items())
text_to_label
# Out:
# {'fear': 0, 'Angry': 1, 'Neutral': 2, 'Happy': 3}

# %%
# Classification Report and confusion matrix
yhat_test = np.argmax(model.predict(X_test), axis=1)
ytest_ = np.argmax(y_test, axis=1)

scikitplot.metrics.plot_confusion_matrix(ytest_, yhat_test, figsize=(7,7))
pyplot.savefig("model_confusion_matrix.png")

test_accu = np.sum(ytest_ == yhat_test) / len(ytest_) * 100
print(f"test accuracy: {round(test_accu, 4)} %\n\n")

print(classification_report(ytest_, yhat_test))
# Out:
# test accuracy: 75.0909 %
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.54      0.61       253
#            1       0.61      0.63      0.62       283
#            2       0.64      0.76      0.70       430
#            3       0.91      0.87      0.89       684
#
#     accuracy                           0.75      1650
#    macro avg       0.72      0.70      0.70      1650
# weighted avg       0.76      0.75      0.75      1650

# %% [markdown]
# The confusion matrix clearly shows that model is doing good job on the class happy but it's performance is not that good on other classes. One of the reason for this could be the fact that these classes have less data as compared to happy.

# %%
np.random.seed(42)
fear_imgs = np.random.choice(np.where(y_test[:, text_to_label["fear"]]==1)[0], size=9, replace=False)
angry_imgs = np.random.choice(np.where(y_test[:, text_to_label["Angry"]]==1)[0], size=9, replace=False)

fig = pyplot.figure(1, (18, 4))

for i, (fear_idx, angry_idx) in enumerate(zip(fear_imgs, angry_imgs)):
        sample_img = X_test[fear_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = pyplot.subplot(2, 9, i+1)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:fear, p:{pred}")

        sample_img = X_test[angry_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]
        
        
        ax = pyplot.subplot(2, 9, i+10)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:angry, p:{pred}")

        pyplot.tight_layout()

# %%
np.random.seed(42)
neutral_imgs = np.random.choice(np.where(y_test[:, text_to_label["Neutral"]]==1)[0], size=9, replace=False)
happy_imgs = np.random.choice(np.where(y_test[:, text_to_label["Happy"]]==1)[0], size=9, replace=False)

fig = pyplot.figure(1, (18, 4))

for i, (fear_idx, angry_idx) in enumerate(zip(neutral_imgs, happy_imgs)):
        sample_img = X_test[fear_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = pyplot.subplot(2, 9, i+1)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:Neutral, p:{pred}")

        sample_img = X_test[angry_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]
        
        ax = pyplot.subplot(2, 9, i+10)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:Happy, p:{pred}")

        pyplot.tight_layout()

# %% [markdown]
# The reason for low accuracy is the data quality. there are miss-classified images in the dataset. Many of them doesn't belong to their true class but are actually looking more likely to the predicted class.
